# %% [markdown]
# Long-term international migration 2.04, main reason for migration

# %%
from gssutils import *

scraper = Scraper('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/' \
                  'longterminternationalmigrationmainreasonformigrationtable204')
scraper
# Out:
# ## Long-term international migration 2.04, main reason for migration, UK and England and Wales
#
# The primary purpose of migrants entering or leaving UK. Estimates of Long-Term International Migration, annual table.
#
# ### Distributions
#
# 1. Long-term international migration 2.04, main reason for migration, UK and England and Wales ([MS Excel Spreadsheet](https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/longterminternationalmigrationmainreasonformigrationtable204/current/2.04ltimmainreasonformigration1991to2016.xls))

# %%
tab = next(t for t in scraper.distribution().as_databaker() if t.name == 'Table 2.04')

# %%
observations = tab.excel_ref("B14").expand(RIGHT).filter(contains_string("Estimate")).expand(DOWN).is_not_blank().is_not_whitespace()
observations
# Out:
# {<L39 80.0>, <P120 -41.0>, <G121 -81.0>, <G55 -88.0>, <L131 -26.0>, <B52 -238.0>, <N66 -23.0>, <E66 -219.0>, <I115 -46.0>, <I114 -44.0>, <E131 -164.0>, <E34 246.0>, <B35 596.0>, <G66 -136.0>, <E57 -143.0>, <N55 -15.0>, <I43 104.0>, <B41 498.0>, <L75 'No'>, <R36 35.0>, <R69 -57.0>, <B118 -291.0>, <L85 65.0>, <R66 -88.0>, <R92 31.0>, <R134 -70.0>, <B106 'No'>, <N83 49.0>, <P92 82.0>, <P109 -23.0>, <P81 44.0>, <L63 -54.0>, <B115 -244.0>, <P95 47.0>, <G112 -62.0>, <P34 66.0>, <R123 -75.0>, <I73 -66.0>, <I56 -43.0>, <P110 -37.0>, <G104 168.0>, <I34 80.0>, <P121 -46.0>, <B22 266.0>, <G38 129.0>, <I61 -67.0>, <I129 -69.0>, <N85 55.0>, <I75 'No'>, <E42 214.0>, <R120 -65.0>, <G29 108.0>, <I125 -66.0>, <N88 74.0>, <L93 94.0>, <P30 107.0>, <N62 -15.0>, <R115 -25.0>, <G101 105.0>, <I60 -71.0>, <B38 567.0>, <E110 -97.0>, <E51 -135.0>, <I57 -63.0>, <L102 66.0>, <R64 -96.0>, <G91 102.0>, <I29 55.0>, <P63 -39.0>, <L83 71.0>, <E101 165.0>, <G42 132.0>, <L61 -59.0>, <L103 83.0>, <B92 480.0>, <N50 -12.
# ...

# %%
CI = observations.shift(RIGHT)
CI
# Out:
# {<J91 12.0>, <C121 31.0>, <J102 11.0>, <J36 14.0>, <Q110 8.0>, <H82 8.0>, <H127 13.0>, <J38 9.0>, <M73 6.0>, <H98 16.0>, <S22 6.0>, <H97 20.0>, <C97 36.0>, <J104 16.0>, <F36 29.0>, <M119 9.0>, <H120 15.0>, <C95 36.0>, <M112 11.0>, <S130 9.0>, <O90 12.0>, <F90 21.0>, <M63 12.0>, <Q57 5.0>, <J105 13.0>, <F52 12.0>, <O74 6.0>, <C22 19.0>, <S58 14.0>, <C133 20.0>, <J82 6.0>, <C34 37.0>, <S45 11.0>, <F89 21.0>, <F44 25.0>, <O124 9.0>, <C120 28.0>, <H72 11.0>, <F115 15.0>, <S113 6.0>, <J28 10.0>, <S59 13.0>, <M35 16.0>, <F45 24.0>, <F31 21.0>, <Q38 5.0>, <C54 28.0>, <J117 9.0>, <Q133 6.0>, <H116 11.0>, <J126 16.0>, <S96 13.0>, <F25 15.0>, <O94 16.0>, <O127 4.0>, <Q123 5.0>, <J131 7.0>, <O106 ''>, <C44 33.0>, <O33 19.0>, <S89 8.0>, <C134 22.0>, <M121 11.0>, <M67 7.0>, <M52 11.0>, <H32 19.0>, <S110 9.0>, <H113 12.0>, <S75 ''>, <S44 8.0>, <H55 16.0>, <O70 5.0>, <J130 7.0>, <J65 12.0>, <Q32 6.0>, <O114 3.0>, <M85 11.0>, <Q34 8.0>, <O22 9.0>, <F56 13.0>, <O72 6.0>, <J55 9.0>, <S66 28.0>, <J71 8
# ...

# %%
Reasonformigration = tab.excel_ref('B12').expand(RIGHT).is_not_blank()
Reasonformigration
# Out:
# {<N12 'Formal study'>, <E12 'Work related'>, <L12 'Accompany / join'>, <R12 'No reason stated2'>, <P12 'Other'>, <B12 'All reasons'>}

# %%
Work = tab.excel_ref('E13').expand(RIGHT).is_not_blank()
Work
# Out:
# {<E13 'All'>, <I13 'Looking for work1'>, <G13 'Definite job'>}

# %%
Geography = tab.excel_ref('A').expand(DOWN).by_index([16,76])
Geography
# Out:
# {<A16 'United Kingdom'>, <A76 'England and Wales'>}

# %%
Flow = tab.excel_ref('A').expand(DOWN).by_index([18,47,78,107])
Flow
# Out:
# {<A107 'Outflow'>, <A18 'Inflow'>, <A47 'Outflow'>, <A78 'Inflow'>}

# %%
Year = tab.excel_ref('A20').expand(DOWN) - Geography - Flow - tab.excel_ref('A').expand(DOWN).by_index([46,75,106,135]) - tab.excel_ref('A135').expand(DOWN) 
Year
# Out:
# {<A66 2008.0>, <A49 1991.0>, <A39 2010.0>, <A62 2004.0>, <A117 1999.0>, <A99 2010.0>, <A41 2012.0>, <A36 2007.0>, <A115 1997.0>, <A133 '2015'>, <A70 2012.0>, <A79 ''>, <A96 2007.0>, <A27 1998.0>, <A85 1996.0>, <A69 2011.0>, <A131 2013.0>, <A63 2005.0>, <A73 '2015'>, <A80 1991.0>, <A43 2014.0>, <A123 2005.0>, <A72 2014.0>, <A59 2001.0>, <A65 2007.0>, <A97 2008.0>, <A32 2003.0>, <A37 2008.0>, <A110 1992.0>, <A127 2009.0>, <A101 2012.0>, <A58 2000.0>, <A95 2006.0>, <A53 1995.0>, <A31 2002.0>, <A52 1994.0>, <A68 2010.0>, <A93 2004.0>, <A28 1999.0>, <A116 1998.0>, <A91 2002.0>, <A26 1997.0>, <A42 2013.0>, <A134 '2016'>, <A132 2014.0>, <A120 2002.0>, <A56 1998.0>, <A51 1993.0>, <A48 ''>, <A121 2003.0>, <A33 2004.0>, <A61 2003.0>, <A35 2006.0>, <A109 1991.0>, <A122 2004.0>, <A55 1997.0>, <A45 '2016'>, <A90 2001.0>, <A67 2009.0>, <A89 2000.0>, <A34 2005.0>, <A128 2010.0>, <A29 2000.0>, <A84 1995.0>, <A100 2011.0>, <A126 2008.0>, <A24 1995.0>, <A40 2011.0>, <A87 1998.0>, <A74 '2016'>, <A94 20
# ...

# %%
Tag = tab.excel_ref('B14').expand(RIGHT).is_not_blank()
Tag
# Out:
# {<M14 '+/-CI'>, <B14 'Estimate'>, <F14 '+/-CI'>, <P14 'Estimate'>, <C14 '+/-CI'>, <G14 'Estimate'>, <O14 '+/-CI'>, <Q14 '+/-CI'>, <H14 '+/-CI'>, <N14 'Estimate'>, <J14 '+/-CI'>, <L14 'Estimate'>, <E14 'Estimate'>, <R14 'Estimate'>, <I14 'Estimate'>, <S14 '+/-CI'>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,LEFT),
            HDim(Geography,'Geography',CLOSEST,ABOVE),
            HDim(Reasonformigration,'Reason for migration',CLOSEST,LEFT),
            HDim(Work,'Work',DIRECTLY,ABOVE),
            HDim(Flow,'Flow',CLOSEST,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People (thousands)'),
            HDim(Tag, 'Tag',DIRECTLY,ABOVE),
            HDim(CI,'CI',DIRECTLY,RIGHT)
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# ...

# %%
new_table = c1.topandas()
new_table
# Out:
#      OBS                          DATAMARKER    Year          Geography  \
# 0                                   Estimate    None               None
# 1                                   Estimate    None               None
# 2                                   Estimate    None               None
# 3                                   Estimate    None               None
# 4                                   Estimate    None               None
# 5                                   Estimate    None               None
# 6                                   Estimate    None               None
# 7                                   Estimate    None               None
# 8    329                                 NaN  1991.0     United Kingdom
# 9     71                                 NaN  1991.0     United Kingdom
# 10    50                                 NaN  1991.0     United Kingdom
# 11    21                                 NaN  1991.0     United Kingdom
# ...

# %%
new_table.count()
# Out:
# OBS                     873
# DATAMARKER               45
# Year                    832
# Geography               865
# Reason for migration    873
# Work                    328
# Flow                    865
# Measure Type            873
# Unit                    873
# Tag                     873
# CI                      873
# dtype: int64

# %%
new_table = new_table[new_table['Year'].isnull() == False]

# %%
# new_table[new_table['DATAMARKER'] != 'None']

# %%
# new_table.OBS.fillna('0', inplace = True)

# %%
# new_table.fillna('None', inplace = True)

# %%
# def user_perc(x,y):
    
#     if str(x) == 'None':
#         return y
# #     else:
#         return 0
    
# new_table['OBS'] = new_table.apply(lambda row: user_perc(row['DATAMARKER'], row['OBS']), axis = 1)

# %%
# new_table[new_table['OBS'] == 'z']

# %%
# new_table[new_table['OBS'] == 0]

# %%
new_table['Reason for migration'] = new_table['Reason for migration'].str.rstrip('2')
# Out:
# /home/alex/.virtualenvs/databaker/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Work'] = new_table['Work'].str.rstrip('1')
# Out:
# /home/alex/.virtualenvs/databaker/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# new_table['Key'] = new_table['Year'] + '/' + new_table['Geography'] + '/' + new_table['Reason for migration'] + '/' + new_table['Flow'] + '/' + new_table['Work']

# %%
# new_table = pd.merge(new_table, new_table[['Key', 'OBS', 'Tag']], how = 'left', left_on = 'Key', right_on = 'Key')

# %%
# new_table  = new_table[new_table['Tag_x'] != new_table['Tag_y']]

# %%
# new_table.drop_duplicates('Key', inplace = True)

# %%
# new_table['OBS_x'] = new_table['OBS_x'].astype(int)

# %%
# new_table['OBS_y'] = pd.to_numeric(new_table['OBS_y'])

# %%
# new_table['OBS_y'].fillna(0, inplace = True)

# %%
# new_table['OBS_y'] = new_table['OBS_y'].astype(int)

# %%
# new_table['Value'] = new_table['OBS_x'].astype(str)

# %%
# new_table['CI'] = new_table['OBS_y'].astype(str)

# %%
# new_table['Value'] = new_table['OBS_x'].astype(str) + ' ± '+ new_table['OBS_y'].astype(str)

# %%
# new_table['Year'] = new_table['Year'].astype(str)

# %%
# new_table['Year'] = pd.to_numeric(new_table['Year'])

# %%
# new_table['Year'] = new_table['Year'].astype(int)

# %%
# new_table['Reason for migration'] = new_table['Reason for migration'] + ':' + new_table['Work']

# %%
new_table = new_table[new_table['OBS'] != '']

# %%
new_table.count()
# Out:
# OBS                     828
# DATAMARKER                0
# Year                    828
# Geography               828
# Reason for migration    828
# Work                    308
# Flow                    828
# Measure Type            828
# Unit                    828
# Tag                     828
# CI                      828
# dtype: int64

# %%
new_table['Value'] = new_table['OBS'].astype(str)

# %%
new_table['Value'] = pd.to_numeric(new_table['Value'], errors='coerce').fillna(0)

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table['CI'] = new_table['CI'].astype(str)

# %%
new_table['CI'] = pd.to_numeric(new_table['CI'], errors='coerce').fillna(0)

# %%
new_table['CI'] = new_table['CI'].astype(int)

# %%
new_table = new_table[new_table['Year'] !=  0 ]

# %%
new_table.dtypes
# Out:
# OBS                     object
# DATAMARKER              object
# Year                    object
# Geography               object
# Reason for migration    object
# Work                    object
# Flow                    object
# Measure Type            object
# Unit                    object
# Tag                     object
# CI                       int64
# Value                    int64
# dtype: object

# %%
new_table.head()
# Out:
#     OBS DATAMARKER    Year       Geography Reason for migration  \
# 8   329        NaN  1991.0  United Kingdom          All reasons
# 9    71        NaN  1991.0  United Kingdom         Work related
# 10   50        NaN  1991.0  United Kingdom         Work related
# 11   21        NaN  1991.0  United Kingdom         Work related
# 12   90        NaN  1991.0  United Kingdom     Accompany / join
#
#                 Work    Flow Measure Type                Unit       Tag  CI  \
# 8               None  Inflow        Count  People (thousands)  Estimate  23
# 9                All  Inflow        Count  People (thousands)  Estimate  10
# 10      Definite job  Inflow        Count  People (thousands)  Estimate   9
# 11  Looking for work  Inflow        Count  People (thousands)  Estimate   4
# 12              None  Inflow        Count  People (thousands)  Estimate  14
#
#     Value
# 8     329
# 9      71
# 10     50
# 11     21
# 12     90

# %%
new_table['Year'] = new_table['Year'].astype(str)

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'])

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
def user_perc(x,y):
    
    if str(x) == 'Work related':
        return x + ': ' + y
    else:
        return x
    
new_table['Reason for migration'] = new_table.apply(lambda row: user_perc(row['Reason for migration'], row['Work']), axis = 1)

# %%
new_table['Geography'] = new_table['Geography'].map(lambda cell:cell.replace('United Kingdom', 'K02000001'))

# %%
new_table['Geography'] = new_table['Geography'].map(lambda cell:cell.replace('England and Wales', 'K04000001'))

# %%
new_table.head(5)
# Out:
#     OBS DATAMARKER  Year  Geography            Reason for migration  \
# 8   329        NaN  1991  K02000001                     All reasons
# 9    71        NaN  1991  K02000001               Work related: All
# 10   50        NaN  1991  K02000001      Work related: Definite job
# 11   21        NaN  1991  K02000001  Work related: Looking for work
# 12   90        NaN  1991  K02000001                Accompany / join
#
#                 Work    Flow Measure Type                Unit       Tag  CI  \
# 8               None  Inflow        Count  People (thousands)  Estimate  23
# 9                All  Inflow        Count  People (thousands)  Estimate  10
# 10      Definite job  Inflow        Count  People (thousands)  Estimate   9
# 11  Looking for work  Inflow        Count  People (thousands)  Estimate   4
# 12              None  Inflow        Count  People (thousands)  Estimate  14
#
#     Value
# 8     329
# 9      71
# 10     50
# 11     21
# 12     90

# %%
# new_table['Reason for migration'] = new_table['Reason for migration'].str.rstrip(':None')

# %%
new_table['Reason for migration'] = new_table['Reason for migration'].map(lambda cell:cell.replace('/', 'or'))

# %%
new_table.count()
# Out:
# OBS                     828
# DATAMARKER                0
# Year                    828
# Geography               828
# Reason for migration    828
# Work                    308
# Flow                    828
# Measure Type            828
# Unit                    828
# Tag                     828
# CI                      828
# Value                   828
# dtype: int64

# %%
new_table = new_table[['Geography','Year','Reason for migration','Flow','Measure Type','Value','CI','Unit']]

# %%
new_table.head(5)
# Out:
#     Geography  Year            Reason for migration    Flow Measure Type  \
# 8   K02000001  1991                     All reasons  Inflow        Count
# 9   K02000001  1991               Work related: All  Inflow        Count
# 10  K02000001  1991      Work related: Definite job  Inflow        Count
# 11  K02000001  1991  Work related: Looking for work  Inflow        Count
# 12  K02000001  1991               Accompany or join  Inflow        Count
#
#     Value  CI                Unit
# 8     329  23  People (thousands)
# 9      71  10  People (thousands)
# 10     50   9  People (thousands)
# 11     21   4  People (thousands)
# 12     90  14  People (thousands)

# %%
from pathlib import Path

destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('tidydata2_4.csv'), index = False)

# %%
scraper.dataset.family = 'migration'

with open(destinationFolder / 'dataset.trig', 'wb') as metadata:
    metadata.write(scraper.generate_trig())

# %% [markdown]
# 832 data, 4 empty spaces 828 observations

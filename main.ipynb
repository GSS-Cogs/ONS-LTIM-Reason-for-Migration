# %% [markdown]
# # Long-term international migration 2.04, main reason for migration

# %%
from gssutils import *

scraper = Scraper('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/' \
                  'longterminternationalmigrationmainreasonformigrationtable204')
scraper
# Out:
# ## Long-term international migration 2.04, main reason for migration, UK and England and Wales
#
# The primary purpose of migrants entering or leaving UK. Estimates of Long-Term International Migration, annual table.
#
# ### Distributions
#
# 1. Long-term international migration 2.04, main reason for migration, UK and England and Wales ([MS Excel Spreadsheet](https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/longterminternationalmigrationmainreasonformigrationtable204/current/2.04ltimmainreasonformigration1991to2017.xls))

# %%
tab = next(t for t in scraper.distribution().as_databaker() if t.name == 'Table 2.04')

# %%
top_left = tab.filter('Year')
top_left.assert_one()
reason = top_left.fill(RIGHT).is_not_blank() | top_left.shift(DOWN).fill(RIGHT).is_not_blank()
year = top_left.fill(DOWN).regex(r'[0-9]{4}(\.0)?')
flow = top_left.fill(DOWN).one_of(['Inflow', 'Outflow'])
geography = top_left.fill(DOWN).one_of(['United Kingdom', 'England and Wales'])
observations = year.fill(RIGHT) & reason.fill(DOWN)
observations_ci = observations.shift(RIGHT)
cs = ConversionSegment(observations, [
    HDim(year, 'Year', DIRECTLY, LEFT),
    HDim(geography, 'Geography', CLOSEST, ABOVE),
    HDim(reason, 'Reason for migration', DIRECTLY, ABOVE),
    HDim(flow, 'Migration Flow', CLOSEST, ABOVE),
    HDimConst('Measure Type', 'Count'),
    HDimConst('Unit','People (thousands)'),
    HDim(observations_ci, 'CI', DIRECTLY, RIGHT)
])                     
savepreviewhtml(cs)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# td.xc17 { background-color: LightGray }
# td.xc18 { background-color: PaleTurquoise }
# td.xc19 { background-color: Tan }
# td.xc20 { background-color: SkyBlue }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { background-color: red; border: thin blue dotted }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0">OBS</td><td class="xc1">Year</td><td class="xc2">Geography</td><td class="xc3">Reason for migration</td><td class="xc4">Migration Flow</td><td class="xc7">CI</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 2.04</caption>
# <tr><td class="" title="0 0"></td><td class="" title="1 0"></td><td class="" title="2 0"></td><td class="" title="3 0"></td><td class="" title="4 0"></td><td class="" title="5 0"></td><td class="" title="6 0"></td><td class="" title="7 0"></td><td class="" title="8 0"></td><td class="" title="9 0"></td><td class="" title="10 0"></td><td class="" title="11 0"></td><td class="" title="12 0"></td><td class="" title="13 0"></td><td class="" title="14 0"></td><td class="" title="15 0"></td><td class="" title="16 0"></td><td class="" title="17 0"></td><td class="" title="18 0"></td></tr>
# <tr><td class="" title="0 1"></td><td class="" title="1 1"></td><td class="" title="2 1"></td><td class="" title="3 1"></td><td class="" title="4 1"></td><td class="" title="5 1"></td><td class="" title="6 1"></td><td class="" title="7 1"></td><td class="" title="8 1"></td><td class="" title="9 1"></td><td class="" title="10 1"></td><td class="" title="11 1"></td><td class="" title="12 1"></td><td class="" title="13 1"></td><td class="" title="14 1"></td><td class="" title="15 1"></td><td class="" title="16 1"></td><td class="" title="17 1"></td><td class="" title="18 1"></td></tr>
# <tr><td class="" title="0 2"></td><td class="" title="1 2"></td><td class="" title="2 2"></td><td class="" title="3 2"></td><td class="" title="4 2">Highlight significant changes over the last year?</td><td class="" title="5 2"></td><td class="" title="6 2"></td><td class="" title="7 2"></td><td class="" title="8 2"></td><td class="" title="9 2"></td><td class="" title="10 2"></td><td class="" title="11 2"></td><td class="" title="12 2"></td><td class="" title="13 2"></td><td class="xn" title="14 2">1</td><td class="" title="15 2"></td><td class="" title="16 2"></td><td class="" title="17 2"></td><td class="" title="18 2"></td></tr>
# <tr><td class="" title="0 3"></td><td class="" title="1 3"></td><td class="" title="2 3"></td><td class="" title="3 3"></td><td class="" title="4 3"></td><td class="" title="5 3"></td><td class="" title="6 3"></td><td class="" title="7 3"></td><td class="" title="8 3"></td><td class="" title="9 3"></td><td class="" title="10 3"></td><td class="" title="11 3"></td><td class="" title="12 3"></td><td class="" title="13 3"></td><td class="" title="14 3"></td><td class="" title="15 3"></td><td class="" title="16 3"></td><td class="" title="17 3"></td><td class="" title="18 3"></td></tr>
# <tr><td class="" title="0 4"></td><td class="" title="1 4"></td><td class="" title="2 4"></td><td class="" title="3 4"></td><td class="" title="4 4"></td><td class="" title="5 4"></td><td class="" title="6 4"></td><td class="" title="7 4"></td><td class="" title="8 4"></td><td class="" title="9 4"></td><td class="" title="10 4"></td><td class="" title="11 4"></td><td class="" title="12 4"></td><td class="" title="13 4"></td><td class="" title="14 4"></td><td class="" title="15 4"></td><td class="" title="16 4"></td><td class="" title="17 4"></td><td class="" title="18 4"></td></tr>
# <tr><td class="" title="0 5"></td><td class="" title="1 5"></td><td class="" title="2 5"></td><td class="" title="3 5"></td><td class="" title="4 5"></td><td class="" title="5 5"></td><td class="" title="6 5"></td><td class="" title="7 5"></td><td class="" title="8 5"></td><td class="" title="9 5"></td><td class="" title="10 5"></td><td class="" title="11 5"></td><td class="" title="12 5"></td><td class="" title="13 5"></td><td class="" title="14 5"></td><td class="" title="15 5"></td><td class="" title="16 5"></td><td class="" title="17 5"></td><td class="" title="18 5"></td></tr>
# <tr><td class="" title="0 6">Table 2.04</td><td class="" title="1 6"></td><td class="" title="2 6"></td><td class="" title="3 6"></td><td class="" title="4 6"></td><td class="" title="5 6"></td><td class="" title="6 6"></td><td class="" title="7 6"></td><td class="" title="8 6"></td><td class="" title="9 6"></td><td class="" title="10 6"></td><td class="" title="11 6"></td><td class="" title="12 6"></td><td class="" title="13 6"></td><td class="" title="14 6"></td><td class="" title="15 6"></td><td class="" title="16 6"></td><td class="" title="17 6"></td><td class="" title="18 6">Series MN</td></tr>
# <tr><td class="" title="0 7"></td><td class="" title="1 7"></td><td class="" title="2 7"></td><td class="" title="3 7"></td><td class="" title="4 7"></td><td class="" title="5 7"></td><td class="" title="6 7"></td><td class="" title="7 7"></td><td class="" title="8 7"></td><td class="" title="9 7"></td><td class="" title="10 7"></td><td class="" title="11 7"></td><td class="" title="12 7"></td><td class="" title="13 7"></td><td class="" title="14 7"></td><td class="" title="15 7"></td><td class="" title="16 7"></td><td class="" title="17 7"></td><td class="" title="18 7"></td></tr>
# <tr><td class="" title="0 8">Long-Term International Migration</td><td class="" title="1 8"></td><td class="" title="2 8"></td><td class="" title="3 8"></td><td class="" title="4 8"></td><td class="" title="5 8"></td><td class="" title="6 8"></td><td class="" title="7 8"></td><td class="" title="8 8"></td><td class="" title="9 8"></td><td class="" title="10 8"></td><td class="" title="11 8"></td><td class="" title="12 8"></td><td class="" title="13 8"></td><td class="" title="14 8"></td><td class="" title="15 8"></td><td class="" title="16 8"></td><td class="" title="17 8"></td><td class="" title="18 8">United Kingdom,</td></tr>
# <tr><td class="" title="0 9">time series, 1991 to 2017</td><td class="" title="1 9"></td><td class="" title="2 9"></td><td class="" title="3 9"></td><td class="" title="4 9"></td><td class="" title="5 9"></td><td class="" title="6 9"></td><td class="" title="7 9"></td><td class="" title="8 9"></td><td class="" title="9 9"></td><td class="" title="10 9"></td><td class="" title="11 9"></td><td class="" title="12 9"></td><td class="" title="13 9"></td><td class="" title="14 9"></td><td class="" title="15 9"></td><td class="" title="16 9"></td><td class="" title="17 9"></td><td class="" title="18 9">England and Wales</td></tr>
# <tr><td class="" title="0 10">Main Reason for Migration</td><td class="" title="1 10"></td><td class="" title="2 10"></td><td class="" title="3 10"></td><td class="" title="4 10"></td><td class="" title="5 10"></td><td class="" title="6 10"></td><td class="" title="7 10"></td><td class="" title="8 10"></td><td class="" title="9 10"></td><td cla

# %%
tidy = cs.topandas()
tidy.rename(columns={'OBS': 'Value'}, inplace=True)
tidy
# Out:
#     Value DATAMARKER    Year          Geography Reason for migration  \
# 0     329        NaN  1991.0     United Kingdom          All reasons
# 1      71        NaN  1991.0     United Kingdom                  All
# 2      50        NaN  1991.0     United Kingdom         Definite job
# 3      21        NaN  1991.0     United Kingdom    Looking for work1
# 4      90        NaN  1991.0     United Kingdom     Accompany / join
# 5      56        NaN  1991.0     United Kingdom         Formal study
# 6      67        NaN  1991.0     United Kingdom                Other
# 7      45        NaN  1991.0     United Kingdom    No reason stated2
# 8     268        NaN  1992.0     United Kingdom          All reasons
# 9      76        NaN  1992.0     United Kingdom                  All
# 10     48        NaN  1992.0     United Kingdom         Definite job
# 11     28        NaN  1992.0     United Kingdom    Looking for work1
# 12     76        NaN  1992.0     United Kingdom     Accompany / join
# 13     42        NaN  1992.0     United Kingdom         Formal study
# 14     45        NaN  1992.0     United Kingdom                Other
# 15     30        NaN  1992.0     United Kingdom    No reason stated2
# 16    266        NaN  1993.0     United Kingdom          All reasons
# 17     83        NaN  1993.0     United Kingdom                  All
# 18     48        NaN  1993.0     United Kingdom         Definite job
# 19     36        NaN  1993.0     United Kingdom    Looking for work1
# 20     74        NaN  1993.0     United Kingdom     Accompany / join
# 21     50        NaN  1993.0     United Kingdom         Formal study
# 22     37        NaN  1993.0     United Kingdom                Other
# 23     21        NaN  1993.0     United Kingdom    No reason stated2
# 24    315        NaN  1994.0     United Kingdom          All reasons
# 25    113        NaN  1994.0     United Kingdom                  All
# 26     58        NaN  1994.0     United Kingdom         Definite job
# 27     56        NaN  1994.0     United Kingdom    Looking for work1
# 28     78        NaN  1994.0     United Kingdom     Accompany / join
# 29     51        NaN  1994.0     United Kingdom         Formal study
# ..    ...        ...     ...                ...                  ...
# 834   -99        NaN  2014.0  England and Wales         Definite job
# 835   -63        NaN  2014.0  England and Wales    Looking for work1
# 836   -25        NaN  2014.0  England and Wales     Accompany / join
# 837   -20        NaN  2014.0  England and Wales         Formal study
# 838   -35        NaN  2014.0  England and Wales                Other
# 839   -42        NaN  2014.0  England and Wales    No reason stated2
# 840  -272        NaN    2015  England and Wales          All reasons
# 841  -152        NaN    2015  England and Wales                  All
# 842   -90        NaN    2015  England and Wales         Definite job
# 843   -62        NaN    2015  England and Wales    Looking for work1
# 844   -24        NaN    2015  England and Wales     Accompany / join
# 845   -23        NaN    2015  England and Wales         Formal study
# 846   -28        NaN    2015  England and Wales                Other
# 847   -45        NaN    2015  England and Wales    No reason stated2
# 848  -309        NaN    2016  England and Wales          All reasons
# 849  -164        NaN    2016  England and Wales                  All
# 850  -107        NaN    2016  England and Wales         Definite job
# 851   -58        NaN    2016  England and Wales    Looking for work1
# 852   -23        NaN    2016  England and Wales     Accompany / join
# 853   -20        NaN    2016  England and Wales         Formal study
# 854   -31        NaN    2016  England and Wales                Other
# 855   -70        NaN    2016  England and Wales    No reason stated2
# 856  -329        NaN    2017  England and Wales          All reasons
# 857  -176        NaN    2017  England and Wales                  All
# 858  -118        NaN    2017  England and Wales         Definite job
# 859   -58        NaN    2017  England and Wales    Looking for work1
# 860   -20        NaN    2017  England and Wales     Accompany / join
# 861   -18        NaN    2017  England and Wales         Formal study
# 862   -40        NaN    2017  England and Wales                Other
# 863   -76        NaN    2017  England and Wales    No reason stated2
#
#     Migration Flow Measure Type                Unit    CI
# 0           Inflow        Count  People (thousands)  23.0
# 1           Inflow        Count  People (thousands)  10.0
# 2           Inflow        Count  People (thousands)   9.0
# 3           Inflow        Count  People (thousands)   4.0
# 4           Inflow        Count  People (thousands)  14.0
# 5           Inflow        Count  People (thousands)  10.0
# 6           Inflow        Count  People (thousands)   7.0
# 7           Inflow        Count  People (thousands)   9.0
# 8           Inflow        Count  People (thousands)  20.0
# 9           Inflow        Count  People (thousands)  10.0
# 10          Inflow        Count  People (thousands)   9.0
# 11          Inflow        Count  People (thousands)   4.0
# 12          Inflow        Count  People (thousands)  12.0
# 13          Inflow        Count  People (thousands)   8.0
# 14          Inflow        Count  People (thousands)   4.0
# 15          Inflow        Count  People (thousands)   9.0
# 16          Inflow        Count  People (thousands)  19.0
# 17          Inflow        Count  People (thousands)  10.0
# 18          Inflow        Count  People (thousands)   8.0
# 19          Inflow        Count  People (thousands)   6.0
# 20          Inflow        Count  People (thousands)  10.0
# 21          Inflow        Count  People (thousands)   9.0
# 22          Inflow        Count  People (thousands)   3.0
# 23          Inflow        Count  People (thousands)   6.0
# 24          Inflow        Count  People (thousands)  23.0
# 25          Inflow        Count  People (thousands)  15.0
# 26          Inflow        Count  People (thousands)  11.0
# 27          Inflow        Count  People (thousands)  11.0
# 28          Inflow        Count  People (thousands)  12.0
# 29          Inflow        Count  People (thousands)   9.0
# ..             ...          ...                 ...   ...
# 834        Outflow        Count  People (thousands)  10.0
# 835        Outflow        Count  People (thousands)  11.0
# 836        Outflow        Count  People (thousands)   5.0
# 837        Outflow        Count  People (thousands)   5.0
# 838        Outflow        Count  People (thousands)   7.0
# 839        Outflow        Count  People (thousands)  11.0
# 840        Outflow        Count  People (thousands)  20.0
# 841        Outflow        Count  People (thousands)  13.0
# 842        Outflow        Count  People (thousands)  10.0
# 843        Outflow        Count  People (thousands)   9.0
# 844        Outflow        Count  People (thousands)   6.0
# 845        Outflow        Count  People (thousands)   5.0
# 846        Outflow        Count  People (thousands)   6.0
# 847        Outflow        Count  People (thousands)  10.0
# 848        Outflow        Count  People (thousands)  22.0
# 849        Outflow        Count  People (thousands)  14.0
# 850        Outflow        Count  People (thousands)  12.0
# 851        Outflow        Count  People (thousands)   8.0
# 852        Outflow        Count  People (thousands)   6.0
# 853        Outflow        Count  People (thousands)   5.0
# 854        Outflow        Count  People (thousands)   5.0
# 855        Outflow        Count  People (thousands)  14.0
# 856        Outflow        Count  People (thousands)  24.0
# 857        Outflow        Count  People (thousands)  16.0
# 858        Outflow        Count  People (thousands)  14.0
# 859        Outflow        Count  People (thousands)   9.0
# 860        Outflow        Count  People (thousands)   5.0
# 861        Outflow        Count  People (thousands)   4.0
# 862        Outflow        Count  People (thousands)   7.0
# 863        Outflow        Count  People (thousands)  16.0
#
# [864 rows x 9 columns]

# %%
tidy['Marker'] = tidy['DATAMARKER'].map(lambda x:'not-available'
                                  if (x == ':')
                                  else (x))

# %%
# tidy = cs.topandas()
# tidy = tidy[pd.isna(tidy['DATAMARKER'])].copy() # Todo: data markers dropped; figure out how to model them
# tidy.drop(columns=['DATAMARKER'], inplace=True)
# tidy.rename(columns={'OBS': 'Value'}, inplace=True)
# tidy

# %%
from IPython.core.display import HTML
for col in tidy:
    if col not in ['Value', 'CI']:
        tidy[col] = tidy[col].astype('category')
        display(HTML(f"<h2>{col}</h2>"))
        display(tidy[col].cat.categories)
# Out:
# <h2>DATAMARKER</h2>
# Index([':'], dtype='object')
# <h2>Year</h2>
# Index(['1991.0', '1992.0', '1993.0', '1994.0', '1995.0', '1996.0', '1997.0',
#        '1998.0', '1999.0', '2000.0', '2001.0', '2002.0', '2003.0', '2004.0',
#        '2005.0', '2006.0', '2007.0', '2008.0', '2009.0', '2010.0', '2011.0',
#        '2012.0', '2013.0', '2014.0', '2015', '2016', '2017'],
#       dtype='object')
# <h2>Geography</h2>
# Index(['England and Wales', 'United Kingdom'], dtype='object')
# <h2>Reason for migration</h2>
# Index(['Accompany / join', 'All', 'All reasons', 'Definite job',
#        'Formal study', 'Looking for work1', 'No reason stated2', 'Other'],
#       dtype='object')
# <h2>Migration Flow</h2>
# Index(['Inflow', 'Outflow'], dtype='object')
# <h2>Measure Type</h2>
# Index(['Count'], dtype='object')
# <h2>Unit</h2>
# Index(['People (thousands)'], dtype='object')
# <h2>Marker</h2>
# Index(['not-available'], dtype='object')

# %%
tidy['Year'].cat.categories = tidy['Year'].cat.categories.map(lambda x: str(int(float(x))))
tidy['Geography'] = tidy['Geography'].cat.rename_categories({
    'United Kingdom': 'K02000001',
    'England and Wales': 'K04000001'
})
tidy['Reason for migration'] = tidy['Reason for migration'].cat.rename_categories({
    'Accompany / join': 'accompany-or-join',
    'All': 'work-related-all',
    'All reasons': 'all-reasons',
    'Definite job': 'work-related-definite-job',
    'Formal study': 'formal-study',
    'Looking for work1': 'work-related-looking-for-work',
    'No reason stated2': 'no-reason-stated',
    'Other': 'other'
})
tidy['Migration Flow'].cat.categories = tidy['Migration Flow'].cat.categories.map(lambda x: pathify(x))
# tidy['Value'] = tidy['Value'].astype(int)
tidy = tidy[['Geography', 'Year', 'Reason for migration', 'Migration Flow',
             'Measure Type','Value','CI','Unit','Marker']]
tidy
# Out:
#      Geography  Year           Reason for migration Migration Flow  \
# 0    K02000001  1991                    all-reasons         inflow
# 1    K02000001  1991               work-related-all         inflow
# 2    K02000001  1991      work-related-definite-job         inflow
# 3    K02000001  1991  work-related-looking-for-work         inflow
# 4    K02000001  1991              accompany-or-join         inflow
# 5    K02000001  1991                   formal-study         inflow
# 6    K02000001  1991                          other         inflow
# 7    K02000001  1991               no-reason-stated         inflow
# 8    K02000001  1992                    all-reasons         inflow
# 9    K02000001  1992               work-related-all         inflow
# 10   K02000001  1992      work-related-definite-job         inflow
# 11   K02000001  1992  work-related-looking-for-work         inflow
# 12   K02000001  1992              accompany-or-join         inflow
# 13   K02000001  1992                   formal-study         inflow
# 14   K02000001  1992                          other         inflow
# 15   K02000001  1992               no-reason-stated         inflow
# 16   K02000001  1993                    all-reasons         inflow
# 17   K02000001  1993               work-related-all         inflow
# 18   K02000001  1993      work-related-definite-job         inflow
# 19   K02000001  1993  work-related-looking-for-work         inflow
# 20   K02000001  1993              accompany-or-join         inflow
# 21   K02000001  1993                   formal-study         inflow
# 22   K02000001  1993                          other         inflow
# 23   K02000001  1993               no-reason-stated         inflow
# 24   K02000001  1994                    all-reasons         inflow
# 25   K02000001  1994               work-related-all         inflow
# 26   K02000001  1994      work-related-definite-job         inflow
# 27   K02000001  1994  work-related-looking-for-work         inflow
# 28   K02000001  1994              accompany-or-join         inflow
# 29   K02000001  1994                   formal-study         inflow
# ..         ...   ...                            ...            ...
# 834  K04000001  2014      work-related-definite-job        outflow
# 835  K04000001  2014  work-related-looking-for-work        outflow
# 836  K04000001  2014              accompany-or-join        outflow
# 837  K04000001  2014                   formal-study        outflow
# 838  K04000001  2014                          other        outflow
# 839  K04000001  2014               no-reason-stated        outflow
# 840  K04000001  2015                    all-reasons        outflow
# 841  K04000001  2015               work-related-all        outflow
# 842  K04000001  2015      work-related-definite-job        outflow
# 843  K04000001  2015  work-related-looking-for-work        outflow
# 844  K04000001  2015              accompany-or-join        outflow
# 845  K04000001  2015                   formal-study        outflow
# 846  K04000001  2015                          other        outflow
# 847  K04000001  2015               no-reason-stated        outflow
# 848  K04000001  2016                    all-reasons        outflow
# 849  K04000001  2016               work-related-all        outflow
# 850  K04000001  2016      work-related-definite-job        outflow
# 851  K04000001  2016  work-related-looking-for-work        outflow
# 852  K04000001  2016              accompany-or-join        outflow
# 853  K04000001  2016                   formal-study        outflow
# 854  K04000001  2016                          other        outflow
# 855  K04000001  2016               no-reason-stated        outflow
# 856  K04000001  2017                    all-reasons        outflow
# 857  K04000001  2017               work-related-all        outflow
# 858  K04000001  2017      work-related-definite-job        outflow
# 859  K04000001  2017  work-related-looking-for-work        outflow
# 860  K04000001  2017              accompany-or-join        outflow
# 861  K04000001  2017                   formal-study        outflow
# 862  K04000001  2017                          other        outflow
# 863  K04000001  2017               no-reason-stated        outflow
#
#     Measure Type Value    CI                Unit Marker
# 0          Count   329  23.0  People (thousands)    NaN
# 1          Count    71  10.0  People (thousands)    NaN
# 2          Count    50   9.0  People (thousands)    NaN
# 3          Count    21   4.0  People (thousands)    NaN
# 4          Count    90  14.0  People (thousands)    NaN
# 5          Count    56  10.0  People (thousands)    NaN
# 6          Count    67   7.0  People (thousands)    NaN
# 7          Count    45   9.0  People (thousands)    NaN
# 8          Count   268  20.0  People (thousands)    NaN
# 9          Count    76  10.0  People (thousands)    NaN
# 10         Count    48   9.0  People (thousands)    NaN
# 11         Count    28   4.0  People (thousands)    NaN
# 12         Count    76  12.0  People (thousands)    NaN
# 13         Count    42   8.0  People (thousands)    NaN
# 14         Count    45   4.0  People (thousands)    NaN
# 15         Count    30   9.0  People (thousands)    NaN
# 16         Count   266  19.0  People (thousands)    NaN
# 17         Count    83  10.0  People (thousands)    NaN
# 18         Count    48   8.0  People (thousands)    NaN
# 19         Count    36   6.0  People (thousands)    NaN
# 20         Count    74  10.0  People (thousands)    NaN
# 21         Count    50   9.0  People (thousands)    NaN
# 22         Count    37   3.0  People (thousands)    NaN
# 23         Count    21   6.0  People (thousands)    NaN
# 24         Count   315  23.0  People (thousands)    NaN
# 25         Count   113  15.0  People (thousands)    NaN
# 26         Count    58  11.0  People (thousands)    NaN
# 27         Count    56  11.0  People (thousands)    NaN
# 28         Count    78  12.0  People (thousands)    NaN
# 29         Count    51   9.0  People (thousands)    NaN
# ..           ...   ...   ...                 ...    ...
# 834        Count   -99  10.0  People (thousands)    NaN
# 835        Count   -63  11.0  People (thousands)    NaN
# 836        Count   -25   5.0  People (thousands)    NaN
# 837        Count   -20   5.0  People (thousands)    NaN
# 838        Count   -35   7.0  People (thousands)    NaN
# 839        Count   -42  11.0  People (thousands)    NaN
# 840        Count  -272  20.0  People (thousands)    NaN
# 841        Count  -152  13.0  People (thousands)    NaN
# 842        Count   -90  10.0  People (thousands)    NaN
# 843        Count   -62   9.0  People (thousands)    NaN
# 844        Count   -24   6.0  People (thousands)    NaN
# 845        Count   -23   5.0  People (thousands)    NaN
# 846        Count   -28   6.0  People (thousands)    NaN
# 847        Count   -45  10.0  People (thousands)    NaN
# 848        Count  -309  22.0  People (thousands)    NaN
# 849        Count  -164  14.0  People (thousands)    NaN
# 850        Count  -107  12.0  People (thousands)    NaN
# 851        Count   -58   8.0  People (thousands)    NaN
# 852        Count   -23   6.0  People (thousands)    NaN
# 853        Count   -20   5.0  People (thousands)    NaN
# 854        Count   -31   5.0  People (thousands)    NaN
# 855        Count   -70  14.0  People (thousands)    NaN
# 856        Count  -329  24.0  People (thousands)    NaN
# 857        Count  -176  16.0  People (thousands)    NaN
# 858        Count  -118  14.0  People (thousands)    NaN
# 859        Count   -58   9.0  People (thousands)    NaN
# 860        Count   -20   5.0  People (thousands)    NaN
# 861        Count   -18   4.0  People (thousands)    NaN
# 862        Count   -40   7.0  People (thousands)    NaN
# 863        Count   -76  16.0  People (thousands)    NaN
#
# [864 rows x 9 columns]

# %%
out = Path('out')
out.mkdir(exist_ok=True, parents=True)

tidy.drop_duplicates().to_csv(out / ('observations.csv'), index = False)

# %%
from gssutils.metadata import THEME

scraper.dataset.family = 'migration'
scraper.dataset.theme = THEME['population']
with open(out / 'dataset.trig', 'wb') as metadata:
    metadata.write(scraper.generate_trig())
